# %% [markdown]
# # WeatherDiffusion UNet Fine-tuning

# %%
import torch

if torch.cuda.is_available():
    print("CUDA (NVIDIA GPU) is available.")
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"  Device {i} Name: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA (NVIDIA GPU) is not available.")
# Out:
# CUDA (NVIDIA GPU) is available.
# Number of CUDA devices: 1
#   Device 0 Name: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
target_dir = '/content/drive/MyDrive/GenImage'
if not os.path.exists(target_dir):
    os.makedirs(target_dir)
    print(f"Created directory: {target_dir}")
os.chdir(target_dir)
print(f"Current directory: {os.getcwd()}")
# Out:
# Current directory: /content/drive/MyDrive/GenImage

# %%
# !git clone https://github.com/Trongnhat191/weatherdiff.git
# %cd weatherdiff/WeatherDiffusion
# Out:
# fatal: destination path 'weatherdiff' already exists and is not an empty directory.
# /content/drive/MyDrive/GenImage/weatherdiff/WeatherDiffusion

# %%
# !pip install pyyaml tensorboard einops pillow scikit-image

# %% [markdown]
# # Install Dependencies

# %%
# !ls -la
# Out:
# calculate_psnr_ssim.py  haze_data/  test/               weatherdiff.ipynb
# configs/                LICENSE     train/
# datasets/               models/     train_diffusion.py
# eval_diffusion.py       README.md   utils/

# %% [markdown]
# # Data prepare

# %%
# !wget https://igi-web.tugraz.at/download/OzdenizciLegensteinTPAMI2023/WeatherDiff64.pth.tar
print("Pretrained model downloaded successfully!")

# %% [markdown]
# # Download Pretrained Model

# %%
# !rm -rf haze_data
# !mkdir -p haze_data
# %cd haze_data
# !wget http://www.vision.ee.ethz.ch/ntire18/o-haze/O-HAZE.zip
print("Dataset downloaded!")
# Out:
# /content/drive/MyDrive/GenImage/weatherdiff/WeatherDiffusion/haze_data
# --2025-11-25 04:47:31--  http://www.vision.ee.ethz.ch/ntire18/o-haze/O-HAZE.zip
# Resolving www.vision.ee.ethz.ch (www.vision.ee.ethz.ch)... 129.132.19.216, 2001:67c:10ec:254::216
# Connecting to www.vision.ee.ethz.ch (www.vision.ee.ethz.ch)|129.132.19.216|:80... connected.
# HTTP request sent, awaiting response... 301
# Location: https://data.vision.ee.ethz.ch/cvl/ntire18//o-haze/O-HAZE.zip [following]
# --2025-11-25 04:47:32--  https://data.vision.ee.ethz.ch/cvl/ntire18//o-haze/O-HAZE.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 573320339 (547M) [application/zip]
# Saving to: ‘O-HAZE.zip’
#
# O-HAZE.zip          100%[===================>] 546.76M  18.9MB/s    in 31s
#
# 2025-11-25 04:48:04 (17.5 MB/s) - ‘O-HAZE.zip’ saved [573320339/573320339]

# %%
# !apt-get install -y unzip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !unzip -q O-HAZE.zip
print("Dataset extracted!")
# Out:
# Archive:  O-HAZE.zip
#    creating: # O-HAZY NTIRE 2018/
#    creating: # O-HAZY NTIRE 2018/GT/
#  extracting: # O-HAZY NTIRE 2018/GT/01_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/02_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/03_outdoor_GT.JPG
#   inflating: # O-HAZY NTIRE 2018/GT/04_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/05_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/06_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/07_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/08_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/09_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/10_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/11_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/12_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/13_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/14_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/15_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/16_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/17_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/18_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/19_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/20_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/21_outdoor_GT.JPG
#  extracting: # O-HAZY NTIRE 2018/GT/22_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/23_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/24_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/25_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/26_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/27_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/28_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/29_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/30_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/31_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/32_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/33_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/34_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/35_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/36_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/37_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/38_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/39_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/40_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/41_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/42_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/43_outdoor_GT.jpg
#   inflating: # O-HAZY NTIRE 2018/GT/44_outdoor_GT.jpg
#  extracting: # O-HAZY NTIRE 2018/GT/45_outdoor_GT.jpg
#    creating: # O-HAZY NTIRE 2018/hazy/
#  extracting: # O-HAZY NTIRE 2018/hazy/01_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/02_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/03_outdoor_hazy.JPG
#   inflating: # O-HAZY NTIRE 2018/hazy/04_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/05_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/06_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/07_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/08_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/09_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/10_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/11_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/12_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/13_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/14_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/15_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/16_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/17_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/18_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/19_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/20_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/21_outdoor_hazy.JPG
#  extracting: # O-HAZY NTIRE 2018/hazy/22_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/23_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/24_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/25_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/26_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/27_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/28_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/29_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/30_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/31_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/32_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/33_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/34_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/35_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/36_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/37_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/38_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/39_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/40_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/41_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/42_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/43_outdoor_hazy.jpg
#  extracting: # O-HAZY NTIRE 2018/hazy/44_outdoor_hazy.jpg
#   inflating: # O-HAZY NTIRE 2018/hazy/45_outdoor_hazy.jpg

# %%
# %cd '# O-HAZY NTIRE 2018'
print(f"Current directory: {os.getcwd()}")
# Out:
# /content/drive/MyDrive/GenImage/weatherdiff/WeatherDiffusion/haze_data/# O-HAZY NTIRE 2018

# %%
import os
import re

folders_to_process = ["./GT/", "./hazy/"]

# Loop through each folder in the list
for folder in folders_to_process:
    # Ensure the folder exists before trying to list its contents
    if not os.path.exists(folder):
        print(f"Skipping folder: {folder} (Does not exist)")
        continue

    print(f"--- Processing folder: {folder} ---")

    for f in os.listdir(folder):
        lower_name = f.lower()
        main_name = None

        # Check for 'gt' pattern
        if '_gt' in lower_name:
            # Splits the name using '_gt' and joins the parts back
            main_name = re.split('_gt', lower_name)[0] + re.split('_gt', lower_name)[1]

        # Check for 'hazy' pattern
        elif '_hazy' in lower_name:
            # Splits the name using '_hazy' and joins the parts back
            main_name = re.split('_hazy', lower_name)[0] + re.split('_hazy', lower_name)[1]

        # Only rename if a pattern was matched and main_name was set
        if main_name:
            old_path = os.path.join(folder, f)
            new_path = os.path.join(folder, main_name)

            # Only rename if the new name is different from the old name
            if old_path != new_path:
                try:
                    os.rename(old_path, new_path)
                    print(f"Renamed: {f} -> {main_name}")
                except Exception as e:
                    print(f"Error renaming {f}: {e}")
            else:
                # This handles cases where f.lower() is already the main_name
                # and you would rename a file to itself.
                pass
        else:
            print(f"Skipping: {f} (No '_gt' or '_hazy' pattern found)")
# Out:
# --- Processing folder: ./GT/ ---
# Renamed: 01_outdoor_GT.jpg -> 01_outdoor.jpg
# Renamed: 02_outdoor_GT.jpg -> 02_outdoor.jpg
# Renamed: 03_outdoor_GT.JPG -> 03_outdoor.jpg
# Renamed: 04_outdoor_GT.jpg -> 04_outdoor.jpg
# Renamed: 05_outdoor_GT.jpg -> 05_outdoor.jpg
# Renamed: 06_outdoor_GT.jpg -> 06_outdoor.jpg
# Renamed: 07_outdoor_GT.jpg -> 07_outdoor.jpg
# Renamed: 08_outdoor_GT.jpg -> 08_outdoor.jpg
# Renamed: 09_outdoor_GT.jpg -> 09_outdoor.jpg
# Renamed: 10_outdoor_GT.jpg -> 10_outdoor.jpg
# Renamed: 11_outdoor_GT.jpg -> 11_outdoor.jpg
# Renamed: 12_outdoor_GT.jpg -> 12_outdoor.jpg
# Renamed: 13_outdoor_GT.jpg -> 13_outdoor.jpg
# Renamed: 14_outdoor_GT.jpg -> 14_outdoor.jpg
# Renamed: 15_outdoor_GT.jpg -> 15_outdoor.jpg
# Renamed: 16_outdoor_GT.jpg -> 16_outdoor.jpg
# Renamed: 17_outdoor_GT.jpg -> 17_outdoor.jpg
# Renamed: 18_outdoor_GT.jpg -> 18_outdoor.jpg
# Renamed: 19_outdoor_GT.jpg -> 19_outdoor.jpg
# Renamed: 20_outdoor_GT.jpg -> 20_outdoor.jpg
# Renamed: 21_outdoor_GT.JPG -> 21_outdoor.jpg
# Renamed: 22_outdoor_GT.jpg -> 22_outdoor.jpg
# Renamed: 23_outdoor_GT.jpg -> 23_outdoor.jpg
# Renamed: 24_outdoor_GT.jpg -> 24_outdoor.jpg
# Renamed: 25_outdoor_GT.jpg -> 25_outdoor.jpg
# Renamed: 26_outdoor_GT.jpg -> 26_outdoor.jpg
# Renamed: 27_outdoor_GT.jpg -> 27_outdoor.jpg
# Renamed: 28_outdoor_GT.jpg -> 28_outdoor.jpg
# Renamed: 29_outdoor_GT.jpg -> 29_outdoor.jpg
# Renamed: 30_outdoor_GT.jpg -> 30_outdoor.jpg
# Renamed: 31_outdoor_GT.jpg -> 31_outdoor.jpg
# Renamed: 32_outdoor_GT.jpg -> 32_outdoor.jpg
# Renamed: 33_outdoor_GT.jpg -> 33_outdoor.jpg
# Renamed: 34_outdoor_GT.jpg -> 34_outdoor.jpg
# Renamed: 35_outdoor_GT.jpg -> 35_outdoor.jpg
# Renamed: 36_outdoor_GT.jpg -> 36_outdoor.jpg
# Renamed: 37_outdoor_GT.jpg -> 37_outdoor.jpg
# Renamed: 38_outdoor_GT.jpg -> 38_outdoor.jpg
# Renamed: 39_outdoor_GT.jpg -> 39_outdoor.jpg
# Renamed: 40_outdoor_GT.jpg -> 40_outdoor.jpg
# Renamed: 41_outdoor_GT.jpg -> 41_outdoor.jpg
# Renamed: 42_outdoor_GT.jpg -> 42_outdoor.jpg
# Renamed: 43_outdoor_GT.jpg -> 43_outdoor.jpg
# Renamed: 44_outdoor_GT.jpg -> 44_outdoor.jpg
# Renamed: 45_outdoor_GT.jpg -> 45_outdoor.jpg
# --- Processing folder: ./hazy/ ---
# Renamed: 01_outdoor_hazy.jpg -> 01_outdoor.jpg
# Renamed: 02_outdoor_hazy.jpg -> 02_outdoor.jpg
# Renamed: 03_outdoor_hazy.JPG -> 03_outdoor.jpg
# Renamed: 04_outdoor_hazy.jpg -> 04_outdoor.jpg
# Renamed: 05_outdoor_hazy.jpg -> 05_outdoor.jpg
# Renamed: 06_outdoor_hazy.jpg -> 06_outdoor.jpg
# Renamed: 07_outdoor_hazy.jpg -> 07_outdoor.jpg
# Renamed: 08_outdoor_hazy.jpg -> 08_outdoor.jpg
# Renamed: 09_outdoor_hazy.jpg -> 09_outdoor.jpg
# Renamed: 10_outdoor_hazy.jpg -> 10_outdoor.jpg
# Renamed: 11_outdoor_hazy.jpg -> 11_outdoor.jpg
# Renamed: 12_outdoor_hazy.jpg -> 12_outdoor.jpg
# Renamed: 13_outdoor_hazy.jpg -> 13_outdoor.jpg
# Renamed: 14_outdoor_hazy.jpg -> 14_outdoor.jpg
# Renamed: 15_outdoor_hazy.jpg -> 15_outdoor.jpg
# Renamed: 16_outdoor_hazy.jpg -> 16_outdoor.jpg
# Renamed: 17_outdoor_hazy.jpg -> 17_outdoor.jpg
# Renamed: 18_outdoor_hazy.jpg -> 18_outdoor.jpg
# Renamed: 19_outdoor_hazy.jpg -> 19_outdoor.jpg
# Renamed: 20_outdoor_hazy.jpg -> 20_outdoor.jpg
# Renamed: 21_outdoor_hazy.JPG -> 21_outdoor.jpg
# Renamed: 22_outdoor_hazy.jpg -> 22_outdoor.jpg
# Renamed: 23_outdoor_hazy.jpg -> 23_outdoor.jpg
# Renamed: 24_outdoor_hazy.jpg -> 24_outdoor.jpg
# Renamed: 25_outdoor_hazy.jpg -> 25_outdoor.jpg
# Renamed: 26_outdoor_hazy.jpg -> 26_outdoor.jpg
# Renamed: 27_outdoor_hazy.jpg -> 27_outdoor.jpg
# Renamed: 28_outdoor_hazy.jpg -> 28_outdoor.jpg
# Renamed: 29_outdoor_hazy.jpg -> 29_outdoor.jpg
# Renamed: 30_outdoor_hazy.jpg -> 30_outdoor.jpg
# Renamed: 31_outdoor_hazy.jpg -> 31_outdoor.jpg
# Renamed: 32_outdoor_hazy.jpg -> 32_outdoor.jpg
# Renamed: 33_outdoor_hazy.jpg -> 33_outdoor.jpg
# Renamed: 34_outdoor_hazy.jpg -> 34_outdoor.jpg
# Renamed: 35_outdoor_hazy.jpg -> 35_outdoor.jpg
# Renamed: 36_outdoor_hazy.jpg -> 36_outdoor.jpg
# Renamed: 37_outdoor_hazy.jpg -> 37_outdoor.jpg
# Renamed: 38_outdoor_hazy.jpg -> 38_outdoor.jpg
# Renamed: 39_outdoor_hazy.jpg -> 39_outdoor.jpg
# Renamed: 40_outdoor_hazy.jpg -> 40_outdoor.jpg
# Renamed: 41_outdoor_hazy.jpg -> 41_outdoor.jpg
# Renamed: 42_outdoor_hazy.jpg -> 42_outdoor.jpg
# Renamed: 43_outdoor_hazy.jpg -> 43_outdoor.jpg
# Renamed: 44_outdoor_hazy.jpg -> 44_outdoor.jpg
# Renamed: 45_outdoor_hazy.jpg -> 45_outdoor.jpg

# %%
# %cd ..
print(f"Current directory: {os.getcwd()}")
# Out:
# /content/drive/MyDrive/GenImage/weatherdiff/WeatherDiffusion/haze_data

# %%
# !mkdir -p train/GT train/hazy test/GT test/hazy
print("Train and test directories created!")

# %%
folder = os.path.join('# O-HAZY NTIRE 2018',"./hazy/")
print(folder)
image_names = []
for f in os.listdir(folder):
    image_names.append(f)
image_names.sort()
print(image_names)
# Out:
# # O-HAZY NTIRE 2018/./hazy/
# ['01_outdoor.jpg', '02_outdoor.jpg', '03_outdoor.jpg', '04_outdoor.jpg', '05_outdoor.jpg', '06_outdoor.jpg', '07_outdoor.jpg', '08_outdoor.jpg', '09_outdoor.jpg', '10_outdoor.jpg', '11_outdoor.jpg', '12_outdoor.jpg', '13_outdoor.jpg', '14_outdoor.jpg', '15_outdoor.jpg', '16_outdoor.jpg', '17_outdoor.jpg', '18_outdoor.jpg', '19_outdoor.jpg', '20_outdoor.jpg', '21_outdoor.jpg', '22_outdoor.jpg', '23_outdoor.jpg', '24_outdoor.jpg', '25_outdoor.jpg', '26_outdoor.jpg', '27_outdoor.jpg', '28_outdoor.jpg', '29_outdoor.jpg', '30_outdoor.jpg', '31_outdoor.jpg', '32_outdoor.jpg', '33_outdoor.jpg', '34_outdoor.jpg', '35_outdoor.jpg', '36_outdoor.jpg', '37_outdoor.jpg', '38_outdoor.jpg', '39_outdoor.jpg', '40_outdoor.jpg', '41_outdoor.jpg', '42_outdoor.jpg', '43_outdoor.jpg', '44_outdoor.jpg', '45_outdoor.jpg']

# %%
import shutil

for image_name in image_names[:40]:
    #move GT images
    src = os.path.join("# O-HAZY NTIRE 2018","GT", image_name)
    dst = os.path.join('train', 'GT')
    shutil.move(src, dst)
    #move hazy images
    src = os.path.join("# O-HAZY NTIRE 2018","hazy", image_name)
    dst = os.path.join('train', 'hazy')
    shutil.move(src, dst)

for image_name in image_names[40:]:
    #move GT images
    src = os.path.join("# O-HAZY NTIRE 2018","GT", image_name)
    dst = os.path.join('test', 'GT')
    shutil.move(src, dst)
    #move hazy images
    src = os.path.join("# O-HAZY NTIRE 2018","hazy", image_name)
    dst = os.path.join('test', 'hazy')
    shutil.move(src, dst)

print(f"Moved {len(image_names[:40])} images to train and {len(image_names[40:])} images to test")

# %% [markdown]
# # Train

# %%
import os

print("Directory structure:")
print(f"Train GT images: {len(os.listdir('train/GT'))}")
print(f"Train hazy images: {len(os.listdir('train/hazy'))}")
print(f"Test GT images: {len(os.listdir('test/GT'))}")
print(f"Test hazy images: {len(os.listdir('test/hazy'))}")
print(f"\nCurrent directory: {os.getcwd()}")

# %% [markdown]
# # Verify Data Structure

# %%
# %cd ..
print(f"Current directory: {os.getcwd()}")
# Out:
# /content/drive/MyDrive/GenImage/weatherdiff/WeatherDiffusion

# %%
import yaml
import os

# Get the current working directory (should be WeatherDiffusion)
base_dir = os.getcwd()
print(f"Base directory: {base_dir}")

# Create config for O-HAZE fine-tuning
config = {
    'data': {
        'dataset': 'OHaze',
        'image_size': 64,
        'channels': 3,
        'num_workers': 4,
        'data_dir': base_dir,
        'conditional': True
    },
    'model': {
        'in_channels': 3,
        'out_ch': 3,
        'ch': 128,
        'ch_mult': [1, 2, 3, 4],
        'num_res_blocks': 2,
        'attn_resolutions': [16],
        'dropout': 0.0,
        'ema_rate': 0.999,
        'ema': True,
        'resamp_with_conv': True
    },
    'diffusion': {
        'beta_schedule': 'linear',
        'beta_start': 0.0001,
        'beta_end': 0.02,
        'num_diffusion_timesteps': 1000
    },
    'training': {
        'patch_n': 16,
        'batch_size': 4,  # Reduced for Colab
        'n_epochs': 500,
        'n_iters': 100000,
        'snapshot_freq': 2000,  # Save more frequently
        'validation_freq': 1000
    },
    'sampling': {
        'batch_size': 2,  # Reduced for Colab
        'last_only': True
    },
    'optim': {
        'weight_decay': 0.0,
        'optimizer': 'Adam',
        'lr': 0.00002,
        'amsgrad': False,
        'eps': 1e-8
    }
}

# Save config file
config_path = os.path.join('configs', 'ohaze.yml')
with open(config_path, 'w') as f:
    yaml.dump(config, f, default_flow_style=False)

print(f"Config file created at: {config_path}")
print("\nConfig contents:")
print(yaml.dump(config, default_flow_style=False))

# %% [markdown]
# # Create Config File for O-HAZE

# %%
# !python train_diffusion.py \
--config "ohaze.yml" \
--resume "WeatherDiff64.pth.tar" \
--sampling_timesteps 25 \
--image_folder "results/images/OHaze/train/"
# Out:
# Using device: cuda
# => using dataset 'MyDataset'
# Data Loaded!
# => creating denoising-diffusion model...
# Found 40 images in ./haze_data/train/hazy
# Found 5 images in ./haze_data/test/hazy
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0.001
# )
# Current learning rate before training: 1e-05
# epoch:  0
# step: 10, loss: 10574.92578125, data time: 1.2765753984451294
# epoch:  1
# step: 20, loss: 7918.0068359375, data time: 0.9964647054672241
# epoch:  2
# step: 30, loss: 6137.77734375, data time: 0.6642642736434936
# epoch:  3
# step: 40, loss: 4485.51171875, data time: 0.855689525604248
# epoch:  4
# step: 50, loss: 3938.232421875, data time: 0.47961785793304446
# epoch:  5
# step: 60, loss: 3282.48193359375, data time: 0.8425339698791504
# epoch:  6
# step: 70, loss: 2287.23828125, data time: 0.6563583850860596
# epoch:  7
# step: 80, loss: 1990.44091796875, data time: 0.9633739233016968
# epoch:  8
# step: 90, loss: 1999.091064453125, data time: 0.8412239074707031
# epoch:  9
# step: 100, loss: 1704.4615478515625, data time: 1.0603546619415283
# epoch:  10
# step: 110, loss: 1504.2529296875, data time: 0.8256670236587524
# epoch:  11
# step: 120, loss: 1718.1351318359375, data time: 0.6810195922851563
# epoch:  12
# step: 130, loss: 1223.1141357421875, data time: 0.9094623327255249
# epoch:  13
# step: 140, loss: 1039.384765625, data time: 0.6250247240066529
# epoch:  14
# step: 150, loss: 1312.475341796875, data time: 0.6308815002441406
# epoch:  135
# step: 1360, loss: 466.814208984375, data time: 0.6794417142868042
# epoch:  136
# step: 1370, loss: 529.9373168945312, data time: 0.926160478591919
# epoch:  137
# step: 1380, loss: 464.43658447265625, data time: 0.6732190847396851
# epoch:  138
# step: 1390, loss: 272.56524658203125, data time: 0.8389346361160278
# epoch:  139
# step: 1400, loss: 173.20530700683594, data time: 0.7843624591827393
# epoch:  140
# step: 1410, loss: 285.2632751464844, data time: 1.0154683589935303
# epoch:  141
# step: 1420, loss: 210.5253143310547, data time: 0.5728338241577149
# epoch:  142
# step: 1430, loss: 184.0210723876953, data time: 0.8771015644073487
# epoch:  143
# step: 1440, loss: 330.8376770019531, data time: 0.9732133150100708
# epoch:  144
# step: 1450, loss: 246.80001831054688, data time: 0.8721294403076172
# epoch:  145
# step: 1460, loss: 227.5928955078125, data time: 0.7232280492782592
# epoch:  146
# step: 1470, loss: 234.5697021484375, data time: 0.8607072830200195
# epoch:  147
# step: 1480, loss: 423.995361328125, data time: 0.9244193792343139
# epoch:  148
# step: 1490, loss: 196.50543212890625, data time: 1.0764219045639039
# epoch:  149
# step: 1500, loss: 236.88729858398438, data time: 0.6629298448562622
# epoch:  150
# step: 1510, loss: 324.46929931640625, data time: 1.0487393379211425
# epoch:  151
# step: 1520, loss: 430.6123046875, data time: 0.7029270648956298
# epoch:  152
# step: 1530, loss: 301.5992736816406, data time: 0.84955735206604
# epoch:  153
# step: 1540, loss: 282.3595275878906, data time: 0.5314555168151855
# epoch:  154
# step: 1550, loss: 362.30023193359375, data time: 0.8674715995788574
# epoch:  155
# step: 1560, loss: 154.81317138671875, data time: 0.6643037319183349
# epoch:  156
# step: 1570, loss: 135.64242553710938, data time: 1.2812204599380492
# epoch:  157
# step: 1580, loss: 231.55020141601562, data time: 0.9190821886062622
# epoch:  158
# step: 1590, loss: 237.23187255859375, data time: 0.6789578914642334
# epoch:  159
# step: 1600, loss: 432.12451171875, data time: 0.8021623611450195
# epoch:  160
# step: 1610, loss: 196.4512481689453, data time: 0.6205570220947265
# epoch:  161
# step: 1620, loss: 174.5372314453125, data time: 0.8747117996215821
# epoch:  162
# step: 1630, loss: 167.53634643554688, data time: 0.8090442657470703
# epoch:  163
# step: 1640, loss: 320.00152587890625, data time: 0.7012452840805053
# epoch:  164

# %%
# Run evaluation (replace checkpoint path with your trained model)
# !python test_ohaze.py --checkpoint "exp/logs/your_checkpoint.pth.tar"

# %%
# Find the latest checkpoint
import glob
checkpoints = glob.glob('exp/logs/*.pth.tar')
if checkpoints:
    latest_checkpoint = max(checkpoints, key=os.path.getctime)
    print(f"Latest checkpoint: {latest_checkpoint}")
else:
    print("No checkpoints found yet")

# %% [markdown]
# # Evaluate the Fine-tuned Model
#
# After training, you can evaluate the model on the test set.

# %%
# Check training outputs
# !ls -lh exp/logs/
# !ls -lh results/images/OHaze/train/ 2>/dev/null || echo "No validation images yet"

# %% [markdown]
# # Monitor Training (Optional)
#
# You can monitor the training progress by checking the saved checkpoints and validation images in the results folder. The model will save checkpoints every 2000 iterations.
